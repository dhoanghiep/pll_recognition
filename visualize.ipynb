# %%
import sys
import os
sys.path.append("/Users/admin/dev/rubiks/cube")
from cube import Cube
from cube.common import reverse_moves

# %%
reverse_moves("R U R' U R U R' F' R U R' U' R' F R2 U' R' U2 R U' R")
# Out:
# "R' U R' U2 R U R2 F' R U R U' R' F R U' R' U' R U' R'"

# %%
cube = Cube()
cube.rotate("x2 M2 U M U2 M' U M2 y2")
#cube.rotate(" U2 M' U M2")
cube.plot()
# Out:
# <Axes3D: title={'center': 'Rubik’s Cube (3‑D View)'}>
